# %% [markdown]
# ##<b> The International Cricket Council (ICC) is the world governing body of cricket. It was founded as the Imperial Cricket Conference in 1909 by representatives from Australia, England and South Africa. It was renamed as the International Cricket Conference in 1965, and took up its current name in 1989. It organises world championship events such as Cricket World Cup, Women's Cricket World Cup, ICC T20 World Cup, ICC Women's T20 World Cup, ICC Champions Trophy and Under-19 Cricket World Cup.</b>
#
# <br>
#
# ## <b> You recently got a lucky break in the field of Data Science. You got a job of Data Scientist at ICC. You are part of the Analytics Team which is involved in pre-match analyses, live-match analyses and post-match analyses. </b>
#
# <br>
#
# ## <b>This data consists of 1417 T20 matches. Each row corresponds to a single T20 match. As a data scientist, you have to first explore the data and check its sanity. </b>
#
# <br>
#
# ## <u><b>Further you are required to do some analyses :</b></u>
# * ### Rename all the column names to their appropriate names, for example meta.created should be renamed as created_date
# * ### Find out the top three venues which hosted the greatest number of matches.
# * ### Find out the pair of cricket teams who played the most number of T20 matches against each other.
# * ### Print the top five teams by their win percentages. Win percentage is defined as the number of matches won divided by the number of matches played and then multiplied by 100.
# * ### Write a function to get the scorecard of each match. This function would take the innings value as argument and return two scorecard dataframes each for one team as shown below. So the first dataframe would contain the top 4 scorers of the team who batted first and the top 4 bowlers of the opponent team. And the second dataframe would contain the top 4 scorers of the team who batted second and the top 4 bowlers of the opponent team.

# %% [markdown]
# # <b><center> A sample scorecard </center></b>

# %% [markdown]
# ![T20 New.jpg](data:image/jpeg;base64,..._...)

# %%
#Import package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Almabetter/Modules/Python for Data Science/Self Projects/EDA on T20 cricket tournament/Copy of International_T20_Data.csv')

# %%
df.tail()
# Out:
#                                                 innings  meta.data_version  \
# 1412  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 1413  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 1414  [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 1415  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1416  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
#
#      meta.created  meta.revision                   info.dates info.gender  \
# 1412   2016-03-05              2  [datetime.date(2016, 3, 4)]        male
# 1413   2016-03-08              1  [datetime.date(2016, 3, 6)]        male
# 1414   2016-02-03              1  [datetime.date(2016, 2, 3)]        male
# 1415   2016-09-12              1  [datetime.date(2016, 9, 6)]        male
# 1416   2016-09-12              1  [datetime.date(2016, 9, 9)]        male
#
#      info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 1412             T20                      6.0            Pakistan          20
# 1413             T20                      8.0               India          20
# 1414             T20                      NaN         Netherlands          20
# 1415             T20                      NaN           Australia          20
# 1416             T20                      4.0           Australia          20
#
#       ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 1412  ...                  NaN                    NaN                1.0
# 1413  ...                  NaN                    NaN                NaN
# 1414  ...                 84.0                    NaN                NaN
# 1415  ...                 85.0                    NaN                NaN
# 1416  ...                  NaN                    NaN                NaN
#
#      info.outcome.method info.outcome.result info.outcome.eliminator  \
# 1412                 NaN                 NaN                     NaN
# 1413                 NaN                 NaN                     NaN
# 1414                 NaN                 NaN                     NaN
# 1415                 NaN                 NaN                     NaN
# 1416                 NaN                 NaN                     NaN
#
#      info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 1412                        NaN                          NaN            NaN
# 1413                        NaN                          NaN            NaN
# 1414                        NaN                          NaN            NaN
# 1415                        NaN                          NaN            NaN
# 1416                        NaN                          NaN            NaN
#
#       info.outcome.bowl_out
# 1412                    NaN
# 1413                    NaN
# 1414                    NaN
# 1415                    NaN
# 1416                    NaN
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1417 non-null   object
#  1   meta.data_version            1417 non-null   float64
#  2   meta.created                 1417 non-null   object
#  3   meta.revision                1417 non-null   int64
#  4   info.dates                   1417 non-null   object
#  5   info.gender                  1417 non-null   object
#  6   info.match_type              1417 non-null   object
#  7   info.outcome.by.wickets      651 non-null    float64
#  8   info.outcome.winner          1372 non-null   object
#  9   info.overs                   1417 non-null   int64
#  10  info.player_of_match         1255 non-null   object
#  11  info.teams                   1417 non-null   object
#  12  info.toss.decision           1417 non-null   object
#  13  info.toss.winner             1417 non-null   object
#  14  info.umpires                 1395 non-null   object
#  15  info.venue                   1417 non-null   object
#  16  info.city                    1228 non-null   object
#  17  info.outcome.by.runs         721 non-null    float64
#  18  info.match_type_number       684 non-null    float64
#  19  info.neutral_venue           328 non-null    float64
#  20  info.outcome.method          51 non-null     object
#  21  info.outcome.result          45 non-null     object
#  22  info.outcome.eliminator      16 non-null     object
#  23  info.supersubs.New Zealand   1 non-null      object
#  24  info.supersubs.South Africa  1 non-null      object
#  25  info.bowl_out                2 non-null      object
#  26  info.outcome.bowl_out        2 non-null      object
# dtypes: float64(5), int64(2), object(20)
# memory usage: 299.0+ KB

# %% [markdown]
# ### Renaming the columns to be required

# %%
df.rename(columns = {'meta.created':'date','info.match_type':'format','info.outcome.winner':'winner','info.player_of_match':'man_of_the_match','info.venue':'venue','info.teams':'teams'}, inplace = True)

# %%
df1 = df[['innings','date','format','winner','venue','teams']].reset_index(drop = True)

# %%
df1.head()
# Out:
#                                              innings        date format  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  2017-02-18    T20
# 1  [{'1st innings': {'team': 'Australia', 'delive...  2017-02-19    T20
# 2  [{'1st innings': {'team': 'Australia', 'delive...  2017-02-23    T20
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...  2016-09-12    T20
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...  2016-06-19    T20
#
#       winner                              venue                       teams
# 0  Sri Lanka           Melbourne Cricket Ground  ['Australia', 'Sri Lanka']
# 1  Sri Lanka     Simonds Stadium, South Geelong  ['Australia', 'Sri Lanka']
# 2  Australia                      Adelaide Oval  ['Australia', 'Sri Lanka']
# 3  Hong Kong  Bready Cricket Club, Magheramason    ['Ireland', 'Hong Kong']
# 4   Zimbabwe                 Harare Sports Club       ['Zimbabwe', 'India']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   innings  1417 non-null   object
#  1   date     1417 non-null   object
#  2   format   1417 non-null   object
#  3   winner   1372 non-null   object
#  4   venue    1417 non-null   object
#  5   teams    1417 non-null   object
# dtypes: object(6)
# memory usage: 66.5+ KB

# %%
def string_to_dict(str):
  return eval(str)


df1['innings'] = df1['innings'].apply(string_to_dict)

# %%
df1['innings']
# Out:
# 0       [{'1st innings': {'team': 'Australia', 'delive...
# 1       [{'1st innings': {'team': 'Australia', 'delive...
# 2       [{'1st innings': {'team': 'Australia', 'delive...
# 3       [{'1st innings': {'team': 'Hong Kong', 'delive...
# 4       [{'1st innings': {'team': 'Zimbabwe', 'deliver...
#                               ...
# 1412    [{'1st innings': {'team': 'Sri Lanka', 'delive...
# 1413    [{'1st innings': {'team': 'Bangladesh', 'deliv...
# 1414    [{'1st innings': {'team': 'Netherlands', 'deli...
# 1415    [{'1st innings': {'team': 'Australia', 'delive...
# 1416    [{'1st innings': {'team': 'Sri Lanka', 'delive...
# Name: innings, Length: 1417, dtype: object

# %% [markdown]
# ### The top three venues which hosted the greatest number of matches.

# %%
df1['venue'].value_counts()[0:3]
# Out:
# Dubai International Cricket Stadium    62
# Sheikh Zayed Stadium                   41
# Shere Bangla National Stadium          39
# Name: venue, dtype: int64

# %%
top_venues = pd.DataFrame(df1['venue'].value_counts()).reset_index().rename(columns = { 'index' : 'venue', 'venue' : 'count'})
top_venues[0:3]
# Out:
#                                  venue  count
# 0  Dubai International Cricket Stadium     62
# 1                 Sheikh Zayed Stadium     41
# 2        Shere Bangla National Stadium     39

# %%
top_venues[0:10].plot(kind  = 'bar', x= 'venue',y = 'count',figsize=(20,7),fontsize=14 , color = 'indigo')
plt.show();

# %% [markdown]
# ### The pair of cricket teams who played the most number of T20 matches against each other.

# %%
def string_to_list(str):
  return eval(str)


df1['teams'] = df1['teams'].apply(string_to_list)

# %%
def sort_teams(team):
  for i in range(0,1417):
    return((sorted(team)))


df1['teams'] = df1['teams'].apply(sort_teams)

# %%
df1[['teams']]
# Out:
#                                     teams
# 0                  [Australia, Sri Lanka]
# 1                  [Australia, Sri Lanka]
# 2                  [Australia, Sri Lanka]
# 3                    [Hong Kong, Ireland]
# 4                       [India, Zimbabwe]
# ...                                   ...
# 1412                [Pakistan, Sri Lanka]
# 1413                  [Bangladesh, India]
# 1414  [Netherlands, United Arab Emirates]
# 1415               [Australia, Sri Lanka]
# 1416               [Australia, Sri Lanka]
#
# [1417 rows x 1 columns]

# %%
teams_with_most_matches = pd.DataFrame(df1['teams'].apply(tuple).value_counts().reset_index()).rename( columns={"index": "Teams", "teams": "Number of T20 matches played"})

# %%
teams_with_most_matches.reset_index(drop = True).head(1)
# Out:
#                   Teams  Number of T20 matches played
# 0  (Australia, England)                            45

# %%
teams_with_most_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 2 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Teams                         310 non-null    object
#  1   Number of T20 matches played  310 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.0+ KB

# %%
teams_with_most_matches[0:10].plot(kind  = 'bar', x= 'Teams',y = 'Number of T20 matches played',figsize=(30,7),fontsize=14 , color = 'crimson')
plt.show();

# %% [markdown]
# ###The top five teams by their win percentages

# %%
teams_with_most_matches
# Out:
#                              Teams  Number of T20 matches played
# 0             (Australia, England)                            45
# 1           (England, West Indies)                            33
# 2            (Australia, Pakistan)                            33
# 3               (Australia, India)                            32
# 4              (England, Pakistan)                            31
# ..                             ...                           ...
# 305                (Italy, Jersey)                             1
# 306             (Denmark, Germany)                             1
# 307           (Malaysia, Maldives)                             1
# 308               (Rwanda, Uganda)                             1
# 309  (India, United Arab Emirates)                             1
#
# [310 rows x 2 columns]

# %%
matches_per_team_unsorted = teams_with_most_matches.explode('Teams')

# %%
matches_per_team_sorted = matches_per_team_unsorted.sort_values(by = 'Teams')
matches_per_team_sorted
# Out:
#            Teams  Number of T20 matches played
# 143  Afghanistan                             2
# 162  Afghanistan                             1
# 206  Afghanistan                             1
# 57   Afghanistan                             5
# 161  Afghanistan                             1
# ..           ...                           ...
# 48      Zimbabwe                             6
# 45      Zimbabwe                             7
# 42      Zimbabwe                             9
# 119     Zimbabwe                             2
# 121     Zimbabwe                             2
#
# [620 rows x 2 columns]

# %%
matches_per_team = matches_per_team_sorted.groupby(['Teams'])['Number of T20 matches played'].sum().reset_index()
matches_per_team
# Out:
#                        Teams  Number of T20 matches played
# 0                Afghanistan                            75
# 1                  Australia                           214
# 2                    Austria                             4
# 3                    Bahrain                             2
# 4                 Bangladesh                           137
# ..                       ...                           ...
# 66      United Arab Emirates                            56
# 67  United States of America                            14
# 68                   Vanuatu                            12
# 69               West Indies                           195
# 70                  Zimbabwe                            76
#
# [71 rows x 2 columns]

# %%
df5  =  df1['winner'].value_counts().reset_index().rename(columns = {'index' : 'Teams', 'winner':'wins'}).sort_values(by = 'Teams')
df5
# Out:
#                        Teams  wins
# 8                Afghanistan    51
# 0                  Australia   132
# 54                   Bahrain     1
# 9                 Bangladesh    50
# 36                   Belgium     3
# 32                   Bermuda     4
# 40                  Botswana     2
# 55                  Bulgaria     1
# 25                    Canada     8
# 30                     China     5
# 44                   Denmark     2
# 1                    England   130
# 22                   Germany    13
# 33                  Guernsey     3
# 18                 Hong Kong    17
# 52              ICC World XI     1
# 2                      India   121
# 45                 Indonesia     2
# 10                   Ireland    48
# 43                     Italy     2
# 37                     Japan     3
# 27                    Jersey     6
# 23                     Kenya    11
# 38                    Kuwait     3
# 49                    Malawi     1
# 20                  Malaysia    15
# 42                  Maldives     2
# 48                Mozambique     1
# 14                   Namibia    25
# 16                     Nepal    22
# 11               Netherlands    38
# 5                New Zealand    97
# 34                   Nigeria     3
# 21                      Oman    14
# 3                   Pakistan   117
# 17          Papua New Guinea    21
# 50               Philippines     1
# 53                  Portugal     1
# 41                     Qatar     2
# 47                   Romania     2
# 35                    Rwanda     3
# 51                     Samoa     1
# 12                  Scotland    33
# 39              Sierra Leone     3
# 24                 Singapore     9
# 4               South Africa   101
# 28                     Spain     5
# 7                  Sri Lanka    69
# 46                  Tanzania     2
# 19                  Thailand    17
# 26                    Uganda     6
# 13      United Arab Emirates    25
# 29  United States of America     5
# 31                   Vanuatu     5
# 6                West Indies    85
# 15                  Zimbabwe    22

# %%
df6 = matches_per_team.merge(df5, how = 'left').sort_values(by = 'wins', ascending = False).reset_index(drop =True)
df6.fillna(value = 0, inplace = True)
df6
# Out:
#            Teams  Number of T20 matches played   wins
# 0      Australia                           214  132.0
# 1        England                           216  130.0
# 2          India                           204  121.0
# 3       Pakistan                           226  117.0
# 4   South Africa                           192  101.0
# ..           ...                           ...    ...
# 66    Luxembourg                             2    0.0
# 67          Mali                             1    0.0
# 68        Norway                             4    0.0
# 69  Saudi Arabia                             1    0.0
# 70   South Korea                             2    0.0
#
# [71 rows x 3 columns]

# %%
df6['win_percent'] = (df6['wins']/df6['Number of T20 matches played'])*100

# %%
df6.sort_values(by = 'win_percent',ascending = False).head()
# Out:
#           Teams  Number of T20 matches played  wins  win_percent
# 34      Belgium                             3   3.0   100.000000
# 28        Spain                             6   5.0    83.333333
# 22      Germany                            17  13.0    76.470588
# 14      Namibia                            34  25.0    73.529412
# 8   Afghanistan                            75  51.0    68.000000

# %% [markdown]
# #### Scorecard of each match

# %%
from ast import literal_eval as le

# %%
def first_innings(innings):
  
  team_batsmen = []
  run_per_ball = []

  for i in le(innings)[0]['1st innings']['deliveries']:
    team_batsmen.append(list(i.values())[0]['batsman'])
    run_per_ball.append(list(i.values())[0]['runs']['batsman'])

  batsman_score = pd.DataFrame(list(zip(team_batsmen , run_per_ball)), columns = ['team_batsmen','run_per_ball'])
  

  top_4_batsmen = pd.DataFrame(batsman_score.groupby('team_batsmen')['run_per_ball'].sum().sort_index())
  top_4_batsmen['balls_played'] = pd.DataFrame(batsman_score['team_batsmen'].value_counts().sort_index())['team_batsmen']
  top_4_batsmen = top_4_batsmen.sort_values("run_per_ball",ascending=False)[0:4]

  top_4_batsmen['score'] = ''
  for k in top_4_batsmen.index:
    top_4_batsmen['score'][k] = str(top_4_batsmen['run_per_ball'][k]) + '(' + str(top_4_batsmen['balls_played'][k]) + ')'

  top_4_batsmen.drop(['run_per_ball','balls_played'],axis=1,inplace=True)

  team_total_runs = 0
  for l in le(innings)[0]['1st innings']['deliveries']:
    team_total_runs = team_total_runs + list(l.values())[0]['runs']['total']

  total_wickets = 0
  for m in le(innings)[0]['1st innings']['deliveries']:
    if 'wicket' in list(m.values())[0].keys():
      total_wickets = total_wickets + 1

  bowler_wickets = {}
  for n in le(innings)[0]['1st innings']['deliveries']:
    if 'wicket' in list(n.values())[0].keys():
      if list(n.values())[0]["wicket"]['kind'] not in ['run out','retired','obstructing the field','hit the ball twice']:
        if list(n.values())[0]['bowler'] in list(bowler_wickets.keys()):
          bowler_wickets[list(n.values())[0]['bowler']] += 1
        else:
          bowler_wickets[list(n.values())[0]['bowler']] = 1

  no_byes = []
  for o in le(innings)[0]['1st innings']['deliveries']:
    if "extras" in list(o.values())[0]:
      if list(list(o.values())[0]['extras'].keys())[0] not in ['byes','legbyes']:
       no_byes.append(list(o.values())[0])
    else:
      no_byes.append(list(o.values())[0])

  bowler_conceded = {}
  for i in no_byes:
    if i['bowler'] in list(bowler_conceded.keys()):
      bowler_conceded[i['bowler']] = bowler_conceded[i['bowler']] + i['runs']['total']
    else:
      bowler_conceded[i['bowler']] = i['runs']['total']

  yes_byes = []
  for i in le(innings)[0]['1st innings']['deliveries']:
    if "extras" in list(i.values())[0]:
      if list(list(i.values())[0]['extras'].keys())[0] in ['byes','legbyes']:
       yes_byes.append(list(i.values())[0])
    else:
      yes_byes.append(list(i.values())[0])

  number_of_balls = []
  for i in yes_byes:
    number_of_balls.append(i['bowler'])

  number_of_balls = pd.DataFrame(pd.DataFrame(number_of_balls).value_counts()/6)

  number_of_balls.rename({0:"no_of_overs"},inplace=True,axis=1)
  number_of_balls.reset_index(inplace=True)
  number_of_balls.rename({0:"Bowler"},inplace=True,axis=1)

  number_of_balls.set_index('Bowler',inplace=True)

  number_of_balls['runs_scored_given'] = ''
  for i in bowler_conceded.keys():
    number_of_balls['runs_scored_given'][i] = bowler_conceded[i]

  number_of_balls['wickets_taken'] = ''
  for i in bowler_wickets.keys():
    number_of_balls['wickets_taken'][i] = bowler_wickets[i]

  number_of_balls['runs_scored_given'].replace({"":0},inplace=True)
  number_of_balls['wickets_taken'].replace({"":0},inplace=True)

  number_of_balls['bowler_economy'] = number_of_balls['runs_scored_given']/number_of_balls['no_of_overs']

  bowler_df = number_of_balls.sort_values(['wickets_taken','bowler_economy'],ascending=[False,True])[:4]

  bowler_df['bowler_stats'] = ''
  for i in bowler_df.index:
    bowler_df['bowler_stats'][i] = str(bowler_df['wickets_taken'][i]) + '-' + str(bowler_df['runs_scored_given'][i]) + "   (" + str(bowler_df['no_of_overs'][i]) + ")"

  bowler_df.drop(['no_of_overs','runs_scored_given','wickets_taken','bowler_economy'],axis=1,inplace=True)
  bowler_df.reset_index(inplace=True)
  top_4_batsmen.reset_index(inplace=True)
  match_result = pd.concat([top_4_batsmen,bowler_df],axis=1)

  match_result['Final Score'] = ''
  match_result['Final Score'][0] = str(team_total_runs) + '-' + str(total_wickets)

  return match_result

# %%
def second_innings(innings):
  
  team_batsmen = []
  run_per_ball = []

  for i in le(innings)[1]['1st innings']['deliveries']:
    team_batsmen.append(list(i.values())[0]['batsman'])
    run_per_ball.append(list(i.values())[0]['runs']['batsman'])

  batsman_score = pd.DataFrame(list(zip(team_batsmen , run_per_ball)), columns = ['team_batsmen','run_per_ball'])
  

  top_4_batsmen = pd.DataFrame(batsman_score.groupby('team_batsmen')['run_per_ball'].sum().sort_index())
  top_4_batsmen['balls_played'] = pd.DataFrame(batsman_score['team_batsmen'].value_counts().sort_index())['team_batsmen']
  top_4_batsmen = top_4_batsmen.sort_values("run_per_ball",ascending=False)[0:4]

  top_4_batsmen['score'] = ''
  for k in top_4_batsmen.index:
    top_4_batsmen['score'][k] = str(top_4_batsmen['run_per_ball'][k]) + '(' + str(top_4_batsmen['balls_played'][k]) + ')'

  top_4_batsmen.drop(['run_per_ball','balls_played'],axis=1,inplace=True)

  team_total_runs = 0
  for l in le(innings)[1]['1st innings']['deliveries']:
    team_total_runs = team_total_runs + list(l.values())[0]['runs']['total']

  total_wickets = 0
  for m in le(innings)[1]['1st innings']['deliveries']:
    if 'wicket' in list(m.values())[0].keys():
      total_wickets = total_wickets + 1

  bowler_wickets = {}
  for n in le(innings)[1]['1st innings']['deliveries']:
    if 'wicket' in list(n.values())[0].keys():
      if list(n.values())[0]["wicket"]['kind'] not in ['run out','retired','obstructing the field','hit the ball twice']:
        if list(n.values())[0]['bowler'] in list(bowler_wickets.keys()):
          bowler_wickets[list(n.values())[0]['bowler']] += 1
        else:
          bowler_wickets[list(n.values())[0]['bowler']] = 1

  no_byes = []
  for o in le(innings)[1]['1st innings']['deliveries']:
    if "extras" in list(o.values())[0]:
      if list(list(o.values())[0]['extras'].keys())[0] not in ['byes','legbyes']:
       no_byes.append(list(o.values())[0])
    else:
      no_byes.append(list(o.values())[0])

  bowler_conceded = {}
  for i in no_byes:
    if i['bowler'] in list(bowler_conceded.keys()):
      bowler_conceded[i['bowler']] = bowler_conceded[i['bowler']] + i['runs']['total']
    else:
      bowler_conceded[i['bowler']] = i['runs']['total']

  yes_byes = []
  for i in le(innings)[1]['1st innings']['deliveries']:
    if "extras" in list(i.values())[0]:
      if list(list(i.values())[0]['extras'].keys())[0] in ['byes','legbyes']:
       yes_byes.append(list(i.values())[0])
    else:
      yes_byes.append(list(i.values())[0])

  number_of_balls = []
  for i in yes_byes:
    number_of_balls.append(i['bowler'])

  number_of_balls = pd.DataFrame(pd.DataFrame(number_of_balls).value_counts()/6)

  number_of_balls.rename({0:"no_of_overs"},inplace=True,axis=1)
  number_of_balls.reset_index(inplace=True)
  number_of_balls.rename({0:"Bowler"},inplace=True,axis=1)

  number_of_balls.set_index('Bowler',inplace=True)

  number_of_balls['runs_scored_given'] = ''
  for i in bowler_conceded.keys():
    number_of_balls['runs_scored_given'][i] = bowler_conceded[i]

  number_of_balls['wickets_taken'] = ''
  for i in bowler_wickets.keys():
    number_of_balls['wickets_taken'][i] = bowler_wickets[i]

  number_of_balls['runs_scored_given'].replace({"":0},inplace=True)
  number_of_balls['wickets_taken'].replace({"":0},inplace=True)

  number_of_balls['bowler_economy'] = number_of_balls['runs_scored_given']/number_of_balls['no_of_overs']

  bowler_df = number_of_balls.sort_values(['wickets_taken','bowler_economy'],ascending=[False,True])[:4]

  bowler_df['bowler_stats'] = ''
  for i in bowler_df.index:
    bowler_df['bowler_stats'][i] = str(bowler_df['wickets_taken'][i]) + '-' + str(bowler_df['runs_scored_given'][i]) + "   (" + str(bowler_df['no_of_overs'][i]) + ")"

  bowler_df.drop(['no_of_overs','runs_scored_given','wickets_taken','bowler_economy'],axis=1,inplace=True)
  bowler_df.reset_index(inplace=True)
  top_4_batsmen.reset_index(inplace=True)
  match_result = pd.concat([top_4_batsmen,bowler_df],axis=1)

  match_result['Final Score'] = ''
  match_result['Final Score'][0] = str(team_total_runs) + '-' + str(total_wickets)

  return match_result

# %%
def final_score_card(innings):
  return pd.concat([first_innings(innings),first_innings(innings)],axis=1)

# %%
final_score_card(df['innings'][6])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_batsmen   score        Bowler  bowler_stats Final Score team_batsmen  \
# 0    KM Jadhav  58(44)   DT Tiripano  3-20   (4.0)       138-6    KM Jadhav
# 1     KL Rahul  22(20)     AG Cremer  1-32   (4.0)                 KL Rahul
# 2     AR Patel  20(11)     N Madziva  1-32   (4.0)                 AR Patel
# 3    AT Rayudu  20(26)  CJ Chibhabha  0-19   (4.0)                AT Rayudu
#
#     score        Bowler  bowler_stats Final Score
# 0  58(44)   DT Tiripano  3-20   (4.0)       138-6
# 1  22(20)     AG Cremer  1-32   (4.0)
# 2  20(11)     N Madziva  1-32   (4.0)
# 3  20(26)  CJ Chibhabha  0-19   (4.0)
